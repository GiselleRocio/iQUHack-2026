# %% [markdown]
# # iQuHack 2026 - Quantum Entanglement Distillation Game
#
# In this game, you design quantum circuits to distill noisy Bell pairs and claim edges in a network.
#
# **Game Flow**: Register -> Select Starting Node -> Design Circuits -> Claim Edges -> Score Points

# %%
pip install -r requirements.txt
# Out:
# Collecting qiskit==2.3.0 (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading qiskit-2.3.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Collecting networkx==3.4.2 (from -r requirements.txt (line 2))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting requests==2.32.5 (from -r requirements.txt (line 3))
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting ipykernel==7.1.0 (from -r requirements.txt (line 4))
#   Downloading ipykernel-7.1.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (3.10.0)
# Collecting rustworkx>=0.15.0 (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading stevedore-5.6.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->-r requirements.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->-r requirements.txt (line 3)) (2026.1.4)
# Collecting comm>=0.1.1 (from ipykernel==7.1.0->-r requirements.txt (line 4))
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (7.34.0)
# Collecting jupyter-client>=8.0.0 (from ipykernel==7.1.0->-r requirements.txt (line 4))
#   Downloading jupyter_client-8.8.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: psutil>=5.7 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (5.9.5)
# Requirement already satisfied: pyzmq>=25 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (26.2.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (5.7.1)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (4.0.1)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (11.3.0)
# Collecting pylatexenc>=1.4 (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (0.13.2)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==7.1.0->-r requirements.txt (line 4)) (4.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn>=0.9.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.8.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (2025.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.5.0)
# Downloading qiskit-2.3.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 52.9 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.8 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 3.8 MB/s eta 0:00:00
# Downloading ipykernel-7.1.0-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 8.4 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading jupyter_client-8.8.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 6.5 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 61.2 MB/s eta 0:00:00
# Downloading stevedore-5.6.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.5 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.4 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=26572fcb5e7e91e2fc454f0aa5595d1eac9e15e31375e4a46c3cd67d35c439b5
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, stevedore, rustworkx, requests, networkx, jedi, comm, qiskit, jupyter-client, ipykernel
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.6.1
#     Uninstalling networkx-3.6.1:
#       Successfully uninstalled networkx-3.6.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 7.4.9
#     Uninstalling jupyter_client-7.4.9:
#       Successfully uninstalled jupyter_client-7.4.9
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 7.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# notebook 6.5.7 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.8.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.8.0 which is incompatible.
# Successfully installed comm-0.2.3 ipykernel-7.1.0 jedi-0.19.2 jupyter-client-8.8.0 networkx-3.4.2 pylatexenc-2.10 qiskit-2.3.0 requests-2.32.5 rustworkx-0.17.1 stevedore-5.6.0

# %%
from client import GameClient
from visualization import GraphTool
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
import json
from pathlib import Path

# %% [markdown]
# ## Session Management
#
# Save/load your session to avoid re-registering.

# %%
SESSION_FILE = Path("session.json")

def save_session(client):
    if client.api_token:
        with open(SESSION_FILE, "w") as f:
            json.dump({"api_token": client.api_token, "player_id": client.player_id, "name": client.name}, f)
        print(f"Session saved.")

def load_session():
    if not SESSION_FILE.exists():
        return None
    with open(SESSION_FILE) as f:
        data = json.load(f)
    client = GameClient(api_token=data.get("api_token"))
    client.player_id = data.get("player_id")
    client.name = data.get("name")
    status = client.get_status()
    if status:
        print(f"Resumed: {client.player_id} | Score: {status.get('score', 0)} | Budget: {status.get('budget', 0)}")
        return client
    return None

# %%
# Try to resume existing session
client = load_session()

if not client:
    print("No saved session. Register below.")
# Out:
# No saved session. Register below.

# %% [markdown]
# ## Step 1: Register
#
# Skip this if you resumed a session above.

# %%
if client and client.api_token:
    print(f"Already registered as {client.player_id}")
else:
    client = GameClient()

    # CHANGE THESE to your unique values
    PLAYER_ID = "GiselleRocio"
    PLAYER_NAME = "GiselleRocio"

    result = client.register(PLAYER_ID, PLAYER_NAME, location="remote")

    if result.get("ok"):
        print(f"Registered! Token: {client.api_token[:20]}...")
        candidates = result["data"].get("starting_candidates", [])
        print(f"\nStarting candidates ({len(candidates)}):")
        for c in candidates:
            print(f"  - {c['node_id']}: {c['utility_qubits']} qubits, +{c['bonus_bell_pairs']} bonus")
        save_session(client)
    else:
        print(f"Failed: {result.get('error', {}).get('message')}")
# Out:
# Registered! Token: Wp0jeQrP09OiQxWtCWnD...
#
# Starting candidates (4):
#   - Groningen, Netherlands: 2 qubits, +0 bonus
#   - Leiden, Netherlands: 1 qubits, +1 bonus
#   - Munich, Germany: 3 qubits, +2 bonus
#   - Surabaya, Indonesia: 4 qubits, +0 bonus
# Session saved.

# %% [markdown]
# ## Step 2: Select Starting Node

# %%
status = client.get_status()

if status.get('starting_node'):
    print(f"Starting node: {status['starting_node']}")
    print(f"Budget: {status['budget']} | Score: {status['score']}")
else:
    print("Select a starting node from the candidates shown above.")
    # Uncomment and modify:
    result = client.select_starting_node("Munich, Germany")
    print(result)
# Out:
# Select a starting node from the candidates shown above.
# {'ok': True, 'data': {'success': True, 'starting_node': 'Munich, Germany', 'score': 44, 'budget': 40}}

# %% [markdown]
# ## Step 3: Explore the Network

# %%
client.print_status()
# Out:
# ==================================================
# Player: GiselleRocio (GiselleRocio)
# Score: 0 | Budget: 40 bell pairs
# Active: Yes
# Starting node: Munich, Germany
# Owned: 1 nodes, 0 edges
# Claimable edges: 4
#   - ['Innsbruck, Austria', 'Munich, Germany']: threshold=0.90, difficulty=1
#   - ['Munich, Germany', 'Salzburg, Austria']: threshold=0.90, difficulty=1
#   - ['Munich, Germany', 'Nuremberg, Germany']: threshold=0.90, difficulty=1
#   ... and 1 more
# ==================================================

# %%
# Visualize the network (focused around your nodes)
viz = GraphTool(client.get_cached_graph())
owned = set(client.get_status().get('owned_nodes', []))
viz.render(owned)

# %% [markdown]
# ## Step 4: Design a Distillation Circuit
#
# For N Bell pairs, qubits are paired outside-in:
# - Pair 0: qubits {0, 2N-1}
# - Pair 1: qubits {1, 2N-2}
# - ...
# - Final pair: qubits {N-1, N}
#
# Design a circuit that improves fidelity through LOCC operations.

# %%
import requests

def safe_claim_edge_with_qasm(client, edge_id, qasm_str, flag_bit: int, num_bell_pairs: int):
    payload = {
        "player_id": client.player_id,
        "edge": [edge_id[0], edge_id[1]],
        "num_bell_pairs": int(num_bell_pairs),
        "circuit_qasm": qasm_str,
        "flag_bit": int(flag_bit),
    }
    try:
        return client._post("/v1/claim_edge", payload)
    except requests.HTTPError as e:
        print("\n=== HTTPError ===")
        print("status:", e.response.status_code)
        try:
            print("response json:", e.response.json())
        except Exception:
            print("response text:", e.response.text[:2000])
        print("payload keys:", list(payload.keys()))
        print("edge:", payload["edge"], "N:", payload["num_bell_pairs"], "flag_bit:", payload["flag_bit"])
        raise

# %%
def qasm_bbpssw_N2():
    # bits: c[0]=a_meas, c[1]=b_meas, c[2]=flag
    # flag_bit = 2
    return """OPENQASM 3.0;
include "stdgates.inc";

qubit[4] q;
bit[3] c;

// Pairing for N=2:
// ancilla pair: (q0, q3)
// data/output pair: (q1, q2)

// Bilateral CNOT: data -> ancilla (local on each side)
cx q[1], q[0];   // Alice local
cx q[2], q[3];   // Bob local

// Measure ancilla qubits
measure q[0] -> c[0];
measure q[3] -> c[1];

// Keep iff equal
c[2] = c[0] ^ c[1];
""", 2

# %%
def qasm_dejmps_lite_N2():
    return """OPENQASM 3.0;
include "stdgates.inc";

qubit[4] q;
bit[3] c;

// Local basis tweaks (DEJMPS-ish):
// Apply H on the ancilla qubits to mix phase/bit information a bit.
// (Still LOCC: only 1-qubit gates.)
h q[0];
h q[3];

// Bilateral CNOT: data -> ancilla (local on each side)
cx q[1], q[0];
cx q[2], q[3];

// Measure ancilla
measure q[0] -> c[0];
measure q[3] -> c[1];

// Keep iff equal
c[2] = c[0] ^ c[1];
""", 2

# %%
def qasm_dejmps_lite_N2():
    return """OPENQASM 3.0;
include "stdgates.inc";

qubit[4] q;
bit[3] c;

// Local basis tweaks (DEJMPS-ish):
// Apply H on the ancilla qubits to mix phase/bit information a bit.
// (Still LOCC: only 1-qubit gates.)
h q[0];
h q[3];

// Bilateral CNOT: data -> ancilla (local on each side)
cx q[1], q[0];
cx q[2], q[3];

// Measure ancilla
measure q[0] -> c[0];
measure q[3] -> c[1];

// Keep iff equal
c[2] = c[0] ^ c[1];
""", 2

# %%
def try_to_cross_threshold(client, edge_id, threshold: float = 0.9, tries_each: int = 10, verbose: bool = True):
    candidates = [
        ("BBPSSW_N2", qasm_bbpssw_N2),
        ("DEJMPS_lite_N2", qasm_dejmps_lite_N2),
    ]

    best = None

    for name, builder in candidates:
        qasm, flag_bit = builder()

        for k in range(tries_each):
            resp = safe_claim_edge_with_qasm(
                client,
                edge_id=edge_id,
                qasm_str=qasm,
                flag_bit=flag_bit,
                num_bell_pairs=2
            )

            data = resp.get("data", resp)

            F = float(data.get("fidelity", 0.0))
            p = float(data.get("success_probability", 0.0))
            thr = float(data.get("threshold", threshold))

            # Estos dos son los que el server realmente usa (según lo que ya viste)
            success = bool(data.get("success", False))
            is_valid = bool(data.get("is_valid", True))  # "válido" en el sentido de request/circuit

            if verbose:
                print(f"[{name} #{k+1}] success={success} is_valid={is_valid} F={F:.4f} p_succ={p:.4f} thr={thr}")

            # Guardar mejor resultado aunque el server no lo marque "success"
            if best is None or F > best["fidelity"]:
                best = {"protocol": name, "fidelity": F, "p_succ": p, "success": success, "is_valid": is_valid, "resp": data}

            # Consideramos “hit” si el server dice success OR si F supera el threshold que reporta
            if success or (F >= thr):
                return {"hit": True, "protocol": name, "fidelity": F, "p_succ": p, "success": success, "is_valid": is_valid, "resp": data}

    return {"hit": False, "best": best}

# %%
claimable = client.get_claimable_edges()
claimable_sorted = sorted(claimable, key=lambda e: (e['difficulty_rating'], e['base_threshold']))
target = claimable_sorted[0]
edge_id = tuple(target["edge_id"])

result = try_to_cross_threshold(client, edge_id, threshold=0.9, tries_each=10, verbose=True)
print(result)
# Out:
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
# {'hit': True, 'protocol': 'BBPSSW_N2', 'fidelity': 0.9697986577181208, 'p_succ': 0.7449999999999997, 'success': True, 'is_valid': False, 'resp': {'success': True, 'is_valid': False, 'fidelity': 0.9697986577181208, 'success_probability': 0.7449999999999997, 'threshold': 0.9, 'remaining_budget': 24, 'is_active': True, 'score': 13, 'reward_changes': []}}

# %%
import time
import random

def _edge_key(edge_id):
    """Normaliza el edge para usarlo como key (orden estable)."""
    a, b = edge_id
    return tuple(sorted((a, b)))

def pick_next_edge(client, conquered_edges, attempts_by_edge, max_attempts_per_edge=20):
    """
    Elige el próximo edge a intentar:
    - que sea claimable
    - que no esté conquistado
    - que no haya superado max_attempts_per_edge
    Priorización: difficulty asc, threshold asc (como venías haciendo),
    con un poquito de ruido para no clavarte siempre en el mismo.
    """
    claimable = client.get_claimable_edges()
    if not claimable:
        return None

    candidates = []
    for e in claimable:
        ek = _edge_key(tuple(e["edge_id"]))
        if ek in conquered_edges:
            continue
        if attempts_by_edge.get(ek, 0) >= max_attempts_per_edge:
            continue

        # score: lo tuyo + micro-aleatoriedad
        score = (e["difficulty_rating"], e["base_threshold"], random.random() * 0.001)
        candidates.append((score, e))

    if not candidates:
        return None

    candidates.sort(key=lambda x: x[0])
    return candidates[0][1]  # el edge dict

def auto_conquer(
    client,
    threshold_default=0.9,
    tries_each=10,
    max_edges_to_claim=50,
    max_attempts_per_edge=20,
    stop_budget_below=2,
    verbose=True,
    sleep_between_edges=0.0
):
    """
    Loop principal:
    - elige edge nuevo
    - corre try_to_cross_threshold
    - si hit => se agrega a conquered_edges
    - si no hit => suma intentos y pasa a otro
    """
    conquered_edges = set()
    attempts_by_edge = {}

    claimed_count = 0

    while True:
        status = client.get_status()
        if not status:
            print("No status (¿registrada?).")
            break

        budget = status.get("budget", 0)
        if budget < stop_budget_below:
            print(f"\n⚠️ Budget bajo ({budget}). Corto.")
            break

        # Sincronizá con el server: por si ya tenés edges conquistados
        for e in status.get("owned_edges", []):
            conquered_edges.add(_edge_key(tuple(e)))

        if claimed_count >= max_edges_to_claim:
            print(f"\n✓ Llegaste al máximo de edges a conquistar ({max_edges_to_claim}).")
            break

        target = pick_next_edge(
            client,
            conquered_edges=conquered_edges,
            attempts_by_edge=attempts_by_edge,
            max_attempts_per_edge=max_attempts_per_edge
        )

        if target is None:
            print("\n✓ No hay más edges “buenos” para intentar (o ya los quemaste a intentos).")
            break

        edge_id = tuple(target["edge_id"])
        ek = _edge_key(edge_id)

        # (Opcional) usar threshold propio del edge si querés
        thr = float(target.get("base_threshold", threshold_default))

        if verbose:
            print("\n" + "="*70)
            print(f"→ Intentando edge: {edge_id} | diff={target['difficulty_rating']} | thr={thr:.2f} | budget={budget}")
            print(f"  intentos previos sobre este edge: {attempts_by_edge.get(ek, 0)} / {max_attempts_per_edge}")

        # Tu función (la que ya tenés)
        result = try_to_cross_threshold(
            client,
            edge_id=edge_id,
            threshold=thr,
            tries_each=tries_each,
            verbose=verbose
        )

        attempts_by_edge[ek] = attempts_by_edge.get(ek, 0) + 1

        if result.get("hit"):
            conquered_edges.add(ek)
            claimed_count += 1
            if verbose:
                print(f"\n🏁 CONQUISTADO: {edge_id} | F={result['fidelity']:.4f} | p={result['p_succ']:.4f} | protocol={result['protocol']}")
        else:
            if verbose:
                best = result.get("best", {})
                if best:
                    print(f"\n✗ No alcanzó threshold. Mejor F visto={best.get('fidelity', 0):.4f} (protocol={best.get('protocol')})")

        if sleep_between_edges > 0:
            time.sleep(sleep_between_edges)

    return {
        "claimed_count": claimed_count,
        "conquered_edges": conquered_edges,
        "attempts_by_edge": attempts_by_edge
    }

# %%
summary = auto_conquer(
    client,
    tries_each=10,
    max_attempts_per_edge=5,
    max_edges_to_claim=30,
    verbose=True
)
print("Edges conquistados:", summary["claimed_count"])
# Out:
# ======================================================================
# → Intentando edge: ('Geneva, Switzerland', 'Lyon, France') | diff=1 | thr=0.90 | budget=40
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Geneva, Switzerland', 'Lyon, France') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Aachen, Germany', 'Eindhoven, Netherlands') | diff=1 | thr=0.90 | budget=38
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Aachen, Germany', 'Eindhoven, Netherlands') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Geneva, Switzerland', 'Grenoble, France') | diff=1 | thr=0.90 | budget=38
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Geneva, Switzerland', 'Grenoble, France') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Grenoble, France', 'Lyon, France') | diff=1 | thr=0.90 | budget=37
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Grenoble, France', 'Lyon, France') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Linz, Austria', 'Vienna, Austria') | diff=1 | thr=0.90 | budget=35
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Linz, Austria', 'Vienna, Austria') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Grenoble, France', 'Turin, Italy') | diff=1 | thr=0.90 | budget=35
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Grenoble, France', 'Turin, Italy') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Antwerp, Belgium', 'Eindhoven, Netherlands') | diff=1 | thr=0.90 | budget=33
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Antwerp, Belgium', 'Eindhoven, Netherlands') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Eindhoven, Netherlands', 'Leuven, Belgium') | diff=1 | thr=0.90 | budget=31
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Eindhoven, Netherlands', 'Leuven, Belgium') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Antwerp, Belgium', 'Lille, France') | diff=1 | thr=0.90 | budget=29
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Antwerp, Belgium', 'Lille, France') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Antwerp, Belgium', 'Ghent, Belgium') | diff=1 | thr=0.90 | budget=27
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Antwerp, Belgium', 'Ghent, Belgium') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Antwerp, Belgium', 'Brussels, Belgium') | diff=1 | thr=0.90 | budget=25
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Antwerp, Belgium', 'Brussels, Belgium') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Ghent, Belgium', 'Leuven, Belgium') | diff=1 | thr=0.90 | budget=23
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Ghent, Belgium', 'Leuven, Belgium') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Brussels, Belgium', 'Lille, France') | diff=1 | thr=0.90 | budget=22
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Brussels, Belgium', 'Lille, France') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Eindhoven, Netherlands', 'Utrecht, Netherlands') | diff=1 | thr=0.90 | budget=20
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=True is_valid=False F=0.9698 p_succ=0.7450 thr=0.9
#
# 🏁 CONQUISTADO: ('Eindhoven, Netherlands', 'Utrecht, Netherlands') | F=0.9698 | p=0.7450 | protocol=BBPSSW_N2
#
# ======================================================================
# → Intentando edge: ('Graz, Austria', 'Salzburg, Austria') | diff=2 | thr=0.90 | budget=18
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #2] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #3] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #4] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #5] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #6] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #7] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #8] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #9] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #10] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [DEJMPS_lite_N2 #1] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #2] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #3] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #4] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #5] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #6] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #7] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #8] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #9] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #10] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
#
# ✗ No alcanzó threshold. Mejor F visto=0.8000 (protocol=DEJMPS_lite_N2)
#
# ======================================================================
# → Intentando edge: ('Lyon, France', 'Turin, Italy') | diff=2 | thr=0.90 | budget=18
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #2] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #3] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #4] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #5] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #6] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #7] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #8] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #9] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #10] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [DEJMPS_lite_N2 #1] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #2] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #3] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #4] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #5] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #6] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #7] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #8] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #9] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #10] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
#
# ✗ No alcanzó threshold. Mejor F visto=0.8000 (protocol=DEJMPS_lite_N2)
#
# ======================================================================
# → Intentando edge: ('Geneva, Switzerland', 'Turin, Italy') | diff=2 | thr=0.90 | budget=18
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #2] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #3] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #4] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #5] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #6] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #7] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #8] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #9] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #10] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [DEJMPS_lite_N2 #1] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #2] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #3] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #4] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #5] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #6] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #7] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #8] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #9] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #10] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
#
# ✗ No alcanzó threshold. Mejor F visto=0.8000 (protocol=DEJMPS_lite_N2)
#
# ======================================================================
# → Intentando edge: ('Grenoble, France', 'Nice, France') | diff=2 | thr=0.90 | budget=18
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #2] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #3] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #4] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #5] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #6] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #7] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #8] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #9] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #10] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [DEJMPS_lite_N2 #1] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #2] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #3] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #4] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #5] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #6] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #7] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #8] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #9] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #10] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
#
# ✗ No alcanzó threshold. Mejor F visto=0.8000 (protocol=DEJMPS_lite_N2)
#
# ======================================================================
# → Intentando edge: ('Linz, Austria', 'Ljubljana, Slovenia') | diff=2 | thr=0.90 | budget=18
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #2] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #3] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #4] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #5] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #6] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #7] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #8] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #9] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #10] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [DEJMPS_lite_N2 #1] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #2] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #3] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #4] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #5] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #6] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #7] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #8] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #9] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #10] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
#
# ✗ No alcanzó threshold. Mejor F visto=0.8000 (protocol=DEJMPS_lite_N2)
#
# ======================================================================
# → Intentando edge: ('Bremen, Germany', 'Dortmund, Germany') | diff=2 | thr=0.90 | budget=18
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #2] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #3] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #4] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #5] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #6] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #7] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #8] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #9] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #10] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [DEJMPS_lite_N2 #1] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #2] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #3] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #4] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #5] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #6] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #7] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #8] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #9] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #10] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
#
# ✗ No alcanzó threshold. Mejor F visto=0.8000 (protocol=DEJMPS_lite_N2)
#
# ======================================================================
# → Intentando edge: ('Graz, Austria', 'Linz, Austria') | diff=2 | thr=0.90 | budget=18
#   intentos previos sobre este edge: 0 / 5
# [BBPSSW_N2 #1] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #2] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #3] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #4] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #5] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #6] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #7] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #8] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #9] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [BBPSSW_N2 #10] success=False is_valid=False F=0.6800 p_succ=1.0000 thr=0.9
# [DEJMPS_lite_N2 #1] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #2] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9
# [DEJMPS_lite_N2 #3] success=False is_valid=False F=0.8000 p_succ=0.8000 thr=0.9

# %% [markdown]
# ## Step 5: Claim an Edge

# %% [markdown]
# ## Step 6: Check Progress

# %%
client.print_status()
# Out:
# ==================================================
# Player: GiselleRocio (GiselleRocio)
# Score: 44 | Budget: 1 bell pairs
# Active: Yes
# Starting node: Munich, Germany
# Owned: 19 nodes, 28 edges
# Claimable edges: 14
#   - ['Geneva, Switzerland', 'Lausanne, Switzerland']: threshold=0.90, difficulty=1
#   - ['Bern, Switzerland', 'Geneva, Switzerland']: threshold=0.90, difficulty=1
#   - ['Lausanne, Switzerland', 'Lyon, France']: threshold=0.90, difficulty=2
#   ... and 11 more
# ==================================================

# %%
# View leaderboard
leaderboard = client.get_leaderboard()["leaderboard"]
print("Leaderboard:")
for i, p in enumerate(leaderboard[:10]):
    print(f"{i+1}. {p.get('player_id', 'Unknown'):20} Score: {p.get('score', 0)}")
# Out:
# Leaderboard:
# 1. diyamagnetism28      Score: 93
# 2. bloch_distiller      Score: 89
# 3. bloch                Score: 87
# 4. bloch_single_run_v8  Score: 85
# 5. Ram_23356_new_version1 Score: 83
# 6. Munich_id            Score: 77
# 7. test_claude_1523b    Score: 70
# 8. orion_the_first      Score: 69
# 9. npqc_1               Score: 63
# 10. willignoresbonuses   Score: 62

# %% [markdown]
# ## Tips
#
# - **Failed attempts are free** - only successful claims cost bell pairs
# - **More bell pairs** can improve fidelity but cost more budget
# - **Vertex rewards** are competitive - top players by claim strength earn rewards
# - **Budget management** is key - if budget reaches 0, you're eliminated
#
# Good luck!

# %%
# Restart game (uncomment to use)
result = client.restart()
print(result)
# Out:
# {'ok': True, 'data': {'success': True, 'budget': 40, 'is_active': True, 'starting_candidates': [{'node_id': 'Groningen, Netherlands', 'utility_qubits': 2, 'bonus_bell_pairs': 0, 'capacity': 5, 'latitude': 53.2194, 'longitude': 6.5665}, {'node_id': 'Leiden, Netherlands', 'utility_qubits': 1, 'bonus_bell_pairs': 1, 'capacity': 5, 'latitude': 52.1601, 'longitude': 4.497}, {'node_id': 'Munich, Germany', 'utility_qubits': 3, 'bonus_bell_pairs': 2, 'capacity': 9, 'latitude': 48.1351, 'longitude': 11.582}, {'node_id': 'Surabaya, Indonesia', 'utility_qubits': 4, 'bonus_bell_pairs': 0, 'capacity': 6, 'latitude': -7.2575, 'longitude': 112.7521}]}}
